# %%
# This Python 3 environment comes with many helpful analytics libraries installed

# %%
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python

# %%
# For example, here's several helpful packages to load

# %%
import numpy as np

# %%
import pandas as pd

# %%
import os

# %%
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
tracks = pd.read_csv('spotify_tracks.csv')
genre = pd.read_csv('train.csv.zip')

# %%
tracks.head()
# Out:
#                  track_id                                  track_name  \
# 0  2r0ROhr7pRN4MXDMT1fEmd                  Leo Das Entry (From "Leo")
# 1  4I38e6Dg52a2o2a8i5Q5PW                                AAO KILLELLE
# 2  59NoiRhnom3lTeRFaBzOev      Mayakiriye Sirikiriye - Orchestral EDM
# 3  5uUqRQd385pvLxC8JX3tXn    Scene Ah Scene Ah - Experimental EDM Mix
# 4  1KaBRg2xgNeCljmyxBH1mo  Gundellonaa X I Am A Disco Dancer - Mashup
#
#                                          artist_name  year  popularity  \
# 0                                Anirudh Ravichander  2024          59
# 1  Anirudh Ravichander, Pravin Mani, Vaishali Sri...  2024          47
# 2           Anirudh Ravichander, Anivee, Alvin Bruno  2024          35
# 3  Anirudh Ravichander, Bharath Sankar, Kabilan, ...  2024          24
# 4  Anirudh Ravichander, Benny Dayal, Leon James, ...  2024          22
#
#                                          artwork_url  \
# 0  https://i.scdn.co/image/ab67616d0000b273ce9c65...
# 1  https://i.scdn.co/image/ab67616d0000b273be1b03...
# 2  https://i.scdn.co/image/ab67616d0000b27334a1dd...
# 3  https://i.scdn.co/image/ab67616d0000b27332e623...
# 4  https://i.scdn.co/image/ab67616d0000b2735a59b6...
#
#                                    album_name  acousticness  danceability  \
# 0                  Leo Das Entry (From "Leo")        0.0241         0.753
# 1                                AAO KILLELLE        0.0851         0.780
# 2      Mayakiriye Sirikiriye (Orchestral EDM)        0.0311         0.457
# 3    Scene Ah Scene Ah (Experimental EDM Mix)        0.2270         0.718
# 4  Gundellonaa X I Am a Disco Dancer (Mashup)        0.0153         0.689
#
#    duration_ms  ...   key  liveness  loudness  mode  speechiness    tempo  \
# 0      97297.0  ...   8.0    0.1000    -5.994   0.0       0.1030  110.997
# 1     207369.0  ...  10.0    0.0951    -5.674   0.0       0.0952  164.995
# 2      82551.0  ...   2.0    0.0831    -8.937   0.0       0.1530  169.996
# 3     115831.0  ...   7.0    0.1240   -11.104   1.0       0.4450  169.996
# 4     129621.0  ...   7.0    0.3450    -9.637   1.0       0.1580  128.961
#
#    time_signature  valence                                          track_url  \
# 0             4.0    0.459  https://open.spotify.com/track/2r0ROhr7pRN4MXD...
# 1             3.0    0.821  https://open.spotify.com/track/4I38e6Dg52a2o2a...
# 2             4.0    0.598  https://open.spotify.com/track/59NoiRhnom3lTeR...
# 3             4.0    0.362  https://open.spotify.com/track/5uUqRQd385pvLxC...
# 4             4.0    0.593  https://open.spotify.com/track/1KaBRg2xgNeCljm...
#
#    language
# 0     Tamil
# 1     Tamil
# 2     Tamil
# 3     Tamil
# 4     Tamil
#
# [5 rows x 22 columns]

# %%
genre.head()
# Out:
#    Unnamed: 0                track_id                 artists  \
# 0           0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1           1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2           2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3           3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4           4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet
#
#                                           album_name  \
# 0                                             Comedy
# 1                                   Ghost (Acoustic)
# 2                                     To Begin Again
# 3  Crazy Rich Asians (Original Motion Picture Sou...
# 4                                            Hold On
#
#                    track_name  popularity  duration_ms  explicit  \
# 0                      Comedy          73       230666     False
# 1            Ghost - Acoustic          55       149610     False
# 2              To Begin Again          57       210826     False
# 3  Can't Help Falling In Love          71       201933     False
# 4                     Hold On          82       198853     False
#
#    danceability  energy  ...  loudness  mode  speechiness  acousticness  \
# 0         0.676  0.4610  ...    -6.746     0       0.1430        0.0322
# 1         0.420  0.1660  ...   -17.235     1       0.0763        0.9240
# 2         0.438  0.3590  ...    -9.734     1       0.0557        0.2100
# 3         0.266  0.0596  ...   -18.515     1       0.0363        0.9050
# 4         0.618  0.4430  ...    -9.681     1       0.0526        0.4690
#
#    instrumentalness  liveness  valence    tempo  time_signature  track_genre
# 0          0.000001    0.3580    0.715   87.917               4     acoustic
# 1          0.000006    0.1010    0.267   77.489               4     acoustic
# 2          0.000000    0.1170    0.120   76.332               4     acoustic
# 3          0.000071    0.1320    0.143  181.740               3     acoustic
# 4          0.000000    0.0829    0.167  119.949               4     acoustic
#
# [5 rows x 21 columns]

# %%
pd.isnull(tracks).sum()
# Out:
# track_id            0
# track_name          0
# artist_name         0
# year                0
# popularity          0
# artwork_url         0
# album_name          0
# acousticness        0
# danceability        0
# duration_ms         0
# energy              0
# instrumentalness    0
# key                 0
# liveness            0
# loudness            0
# mode                0
# speechiness         0
# tempo               0
# time_signature      0
# valence             0
# track_url           0
# language            0
# dtype: int64

# %%
tracks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62317 entries, 0 to 62316
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   track_id          62317 non-null  object
#  1   track_name        62317 non-null  object
#  2   artist_name       62317 non-null  object
#  3   year              62317 non-null  int64
#  4   popularity        62317 non-null  int64
#  5   artwork_url       62317 non-null  object
#  6   album_name        62317 non-null  object
#  7   acousticness      62317 non-null  float64
#  8   danceability      62317 non-null  float64
#  9   duration_ms       62317 non-null  float64
#  10  energy            62317 non-null  float64
#  11  instrumentalness  62317 non-null  float64
#  12  key               62317 non-null  float64
#  13  liveness          62317 non-null  float64
#  14  loudness          62317 non-null  float64
#  15  mode              62317 non-null  float64
#  16  speechiness       62317 non-null  float64
#  17  tempo             62317 non-null  float64
#  18  time_signature    62317 non-null  float64
#  19  valence           62317 non-null  float64
#  20  track_url         62317 non-null  object
#  21  language          62317 non-null  object
# dtypes: float64(13), int64(2), object(7)
# memory usage: 10.5+ MB

# %%
tracks.describe().transpose()
# Out:
#                     count           mean            std       min  \
# year              62317.0    2014.425935       9.645113    1971.0
# popularity        62317.0      15.358361      18.626908       0.0
# acousticness      62317.0       0.362292       0.314609      -1.0
# danceability      62317.0       0.596807       0.186209      -1.0
# duration_ms       62317.0  242527.040021  112999.932607    5000.0
# energy            62317.0       0.602496       0.246144      -1.0
# instrumentalness  62317.0       0.146215       0.307804      -1.0
# key               62317.0       5.101658       3.553469      -1.0
# liveness          62317.0       0.194143       0.172030      -1.0
# loudness          62317.0     -65.103433    2369.051478 -100000.0
# mode              62317.0       0.586052       0.493682      -1.0
# speechiness       62317.0       0.087722       0.115150      -1.0
# tempo             62317.0     117.931247      28.509459      -1.0
# time_signature    62317.0       3.857086       0.502660      -1.0
# valence           62317.0       0.495226       0.264787      -1.0
#
#                           25%            50%          75%          max
# year                2011.0000    2017.000000    2022.0000     2024.000
# popularity             0.0000       7.000000      26.0000       93.000
# acousticness           0.0671       0.286000       0.6320        0.996
# danceability           0.4970       0.631000       0.7300        0.986
# duration_ms       192160.0000  236267.000000  286240.0000  4581483.000
# energy                 0.4400       0.639000       0.8030        1.000
# instrumentalness       0.0000       0.000025       0.0152        0.999
# key                    2.0000       5.000000       8.0000       11.000
# liveness               0.0932       0.125000       0.2430        0.998
# loudness             -10.7270      -7.506000      -5.4560        1.233
# mode                   0.0000       1.000000       1.0000        1.000
# speechiness            0.0367       0.048900       0.0891        0.959
# tempo                 95.9420     117.991000     135.0810      239.970
# time_signature         4.0000       4.000000       4.0000        5.000
# valence                0.2920       0.507000       0.7100        0.995

# %%
most = tracks.query('popularity > 90', inplace = False).sort_values('popularity', ascending = False)
most[:10]
# Out:
#                      track_id       track_name            artist_name  year  \
# 49479  0OA00aPt3BV10qeMIs3meW        Big Dawgs     Hanumankind, Kalmi  2024
# 26432  0VjIjW4GlUZAMYd2vXMi3b  Blinding Lights             The Weeknd  2020
# 26580  7MXVkk9YMctZqd1Srtv4MB          Starboy  The Weeknd, Daft Punk  2016
#
#        popularity                                        artwork_url  \
# 49479          93  https://i.scdn.co/image/ab67616d0000b273d9afe5...
# 26432          91  https://i.scdn.co/image/ab67616d0000b2738863bc...
# 26580          91  https://i.scdn.co/image/ab67616d0000b2734718e2...
#
#         album_name  acousticness  danceability  duration_ms  ...  key  \
# 49479    Big Dawgs       0.02350         0.464     190667.0  ...  4.0
# 26432  After Hours       0.00146         0.514     200040.0  ...  1.0
# 26580      Starboy       0.14100         0.679     230453.0  ...  7.0
#
#        liveness  loudness  mode  speechiness    tempo  time_signature  \
# 49479    0.3630    -3.202   0.0       0.1610  180.098             4.0
# 26432    0.0897    -5.934   1.0       0.0598  171.005             4.0
# 26580    0.1370    -7.015   1.0       0.2760  186.003             4.0
#
#        valence                                          track_url  language
# 49479    0.262  https://open.spotify.com/track/0OA00aPt3BV10qe...   English
# 26432    0.334  https://open.spotify.com/track/0VjIjW4GlUZAMYd...   English
# 26580    0.486  https://open.spotify.com/track/7MXVkk9YMctZqd1...   English
#
# [3 rows x 22 columns]

# %%
least = tracks.sort_values('popularity', ascending = True).head(10)
least
# Out:
#                      track_id                     track_name  \
# 38054  0lV9vfSUbv242tfvr4UJmH           Locked Out of Heaven
# 49621  4mLTQTnjASz2cyNrdSGajG                    Puthusa Oru
# 40237  5T6RbU0c8u2BAiiiGBCOPt            Thambala Sundariyae
# 40324  4QRWPevIlr920AjgLRBiwD      Nandavanam Poothirikkudhu
# 40325  5Gtk81L3vj3VebhwUq3KkK             Raathiri Poothathu
# 61335  6fB5tQyTx3joWUUchHJs4K  Chapter 201 - Nowhere to Hide
# 40326  3Qt2ewtK9B8Fy0i8pqPELA                      Sollatuma
# 61336  2XMrgT7uHF5HGyP5MU0n3l   Chapter 26 - Nowhere to Hide
# 61337  3Xee7EjvEmdHGklr8JQqsK  Chapter 134 - Nowhere to Hide
# 61338  1S99KEcWhxihxejmwZiWE0  Chapter 154 - Nowhere to Hide
#
#                                              artist_name  year  popularity  \
# 38054                                         Bruno Mars  2024           0
# 49621  Ilaiyaraaja, Vaali, K. S. Chithra, Malaysia Va...  1993           0
# 40237  Ilaiyaraaja, Malaysia Vasudevan, S. P. Sailaja...  1986           0
# 40324                Ilaiyaraaja, S. P. Balasubrahmanyam  1988           0
# 40325                                        Ilaiyaraaja  1988           0
# 61335                         Keri Beevis, Shakira Shute  2024           0
# 40326                               Ilaiyaraaja, Sunanda  1988           0
# 61336                         Keri Beevis, Shakira Shute  2024           0
# 61337                         Keri Beevis, Shakira Shute  2024           0
# 61338                         Keri Beevis, Shakira Shute  2024           0
#
#                                              artwork_url  \
# 38054  https://i.scdn.co/image/ab67616d0000b273c1c83d...
# 49621  https://i.scdn.co/image/ab67616d0000b273c1ead7...
# 40237  https://i.scdn.co/image/ab67616d0000b2736d5a5c...
# 40324  https://i.scdn.co/image/ab67616d0000b2733ca90f...
# 40325  https://i.scdn.co/image/ab67616d0000b27342d920...
# 61335  https://i.scdn.co/image/ab67616d0000b273bf257e...
# 40326  https://i.scdn.co/image/ab67616d0000b273a7fbc9...
# 61336  https://i.scdn.co/image/ab67616d0000b273bf257e...
# 61337  https://i.scdn.co/image/ab67616d0000b273bf257e...
# 61338  https://i.scdn.co/image/ab67616d0000b273bf257e...
#
#                                               album_name  acousticness  \
# 38054                 Monthly Best Pop Hits - April 2024         0.049
# 49621  Udan Pirappu (Original Motion Picture Soundtrack)         0.730
# 40237  Kannukku Mai Ezhuthu (Original Motion Picture ...         0.854
# 40324         Illam (Original Motion Picture Soundtrack)         0.667
# 40325   Dhayam Onnu (Original Motion Picture Soundtrack)         0.900
# 61335                       Nowhere to Hide (Unabridged)         0.440
# 40326  Sakkarai Panthal (Original Motion Picture Soun...         0.906
# 61336                       Nowhere to Hide (Unabridged)         0.372
# 61337                       Nowhere to Hide (Unabridged)         0.584
# 61338                       Nowhere to Hide (Unabridged)         0.487
#
#        danceability  duration_ms  ...   key  liveness  loudness  mode  \
# 38054         0.726     233478.0  ...   5.0    0.3090    -4.165   1.0
# 49621         0.610     302933.0  ...  10.0    0.2430    -6.819   1.0
# 40237         0.710     277693.0  ...  10.0    0.6300   -11.800   1.0
# 40324         0.703     304413.0  ...   2.0    0.1130    -5.474   0.0
# 40325         0.582     277473.0  ...   2.0    0.0892   -12.402   1.0
# 61335         0.675     186595.0  ...   0.0    0.1140   -20.407   0.0
# 40326         0.676     266520.0  ...   0.0    0.3110   -11.557   0.0
# 61336         0.622     183882.0  ...   5.0    0.3360   -21.534   0.0
# 61337         0.720     184146.0  ...   5.0    0.5490   -19.888   0.0
# 61338         0.643     182898.0  ...   5.0    0.1100   -19.886   0.0
#
#        speechiness    tempo  time_signature  valence  \
# 38054       0.0431  143.994             4.0    0.866
# 49621       0.0835  175.437             3.0    0.923
# 40237       0.0871  133.695             4.0    0.783
# 40324       0.0703   93.660             4.0    0.714
# 40325       0.0782   76.170             4.0    0.796
# 61335       0.9320   80.647             1.0    0.292
# 40326       0.0627  144.225             4.0    0.898
# 61336       0.9410   80.287             1.0    0.342
# 61337       0.9290  116.382             3.0    0.545
# 61338       0.9500   89.092             5.0    0.410
#
#                                                track_url  language
# 38054  https://open.spotify.com/track/0lV9vfSUbv242tf...   English
# 49621  https://open.spotify.com/track/4mLTQTnjASz2cyN...     Tamil
# 40237  https://open.spotify.com/track/5T6RbU0c8u2BAii...     Tamil
# 40324  https://open.spotify.com/track/4QRWPevIlr920Aj...     Tamil
# 40325  https://open.spotify.com/track/5Gtk81L3vj3Vebh...     Tamil
# 61335  https://open.spotify.com/track/6fB5tQyTx3joWUU...   English
# 40326  https://open.spotify.com/track/3Qt2ewtK9B8Fy0i...     Tamil
# 61336  https://open.spotify.com/track/2XMrgT7uHF5HGyP...   English
# 61337  https://open.spotify.com/track/3Xee7EjvEmdHGkl...   English
# 61338  https://open.spotify.com/track/1S99KEcWhxihxej...   English
#
# [10 rows x 22 columns]

# %%
tracks['duration'] = tracks['duration_ms'].apply (lambda x : round(x/1000))
tracks.drop('duration_ms', inplace = True, axis=1)
tracks.duration.head()
# Out:
# 0     97
# 1    207
# 2     83
# 3    116
# 4    130
# Name: duration, dtype: int64

# %%
cm = tracks.drop(['key','mode'], axis=1).corr(method = 'pearson')
plt.figure(figsize=(14,6))
map = sns.heatmap(cm, annot = True, fmt = '.1g', vmin=-1, vmax=1, center=0, cmap='inferno', linewidths=1, linecolor='Black')
map.set_title('Correlation Heatmap between Variable')
map.set_xticklabels(map.get_xticklabels(), rotation=90)
# Out:
# C:\Users\Rolly\AppData\Local\Temp\ipykernel_18608\1227556501.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   cm = tracks.drop(['key','mode'], axis=1).corr(method = 'pearson')
# [Text(0.5, 0, 'year'),
#  Text(1.5, 0, 'popularity'),
#  Text(2.5, 0, 'acousticness'),
#  Text(3.5, 0, 'danceability'),
#  Text(4.5, 0, 'energy'),
#  Text(5.5, 0, 'instrumentalness'),
#  Text(6.5, 0, 'liveness'),
#  Text(7.5, 0, 'loudness'),
#  Text(8.5, 0, 'speechiness'),
#  Text(9.5, 0, 'tempo'),
#  Text(10.5, 0, 'time_signature'),
#  Text(11.5, 0, 'valence'),
#  Text(12.5, 0, 'duration')]

# %%
sam = tracks.sample(int(0.004 * len(tracks)))
len(sam)
# Out:
# 249

# %%
plt.figure(figsize=(10,6))
sns.regplot(data=sam, y='loudness', x='energy', color='c').set(title='Loudness vs Energy Correlation')
# Out:
# [Text(0.5, 1.0, 'Loudness vs Energy Correlation')]

# %%
plt.figure(figsize=(10,6))
sns.regplot(data=sam, y='popularity', x='acousticness', color='b').set(title='Popularity vs Acousticness Correlation')
# Out:
# [Text(0.5, 1.0, 'Popularity vs Acousticness Correlation')]

# %%
tracks.head()
# Out:
#                  track_id                                  track_name  \
# 0  2r0ROhr7pRN4MXDMT1fEmd                  Leo Das Entry (From "Leo")
# 1  4I38e6Dg52a2o2a8i5Q5PW                                AAO KILLELLE
# 2  59NoiRhnom3lTeRFaBzOev      Mayakiriye Sirikiriye - Orchestral EDM
# 3  5uUqRQd385pvLxC8JX3tXn    Scene Ah Scene Ah - Experimental EDM Mix
# 4  1KaBRg2xgNeCljmyxBH1mo  Gundellonaa X I Am A Disco Dancer - Mashup
#
#                                          artist_name  year  popularity  \
# 0                                Anirudh Ravichander  2024          59
# 1  Anirudh Ravichander, Pravin Mani, Vaishali Sri...  2024          47
# 2           Anirudh Ravichander, Anivee, Alvin Bruno  2024          35
# 3  Anirudh Ravichander, Bharath Sankar, Kabilan, ...  2024          24
# 4  Anirudh Ravichander, Benny Dayal, Leon James, ...  2024          22
#
#                                          artwork_url  \
# 0  https://i.scdn.co/image/ab67616d0000b273ce9c65...
# 1  https://i.scdn.co/image/ab67616d0000b273be1b03...
# 2  https://i.scdn.co/image/ab67616d0000b27334a1dd...
# 3  https://i.scdn.co/image/ab67616d0000b27332e623...
# 4  https://i.scdn.co/image/ab67616d0000b2735a59b6...
#
#                                    album_name  acousticness  danceability  \
# 0                  Leo Das Entry (From "Leo")        0.0241         0.753
# 1                                AAO KILLELLE        0.0851         0.780
# 2      Mayakiriye Sirikiriye (Orchestral EDM)        0.0311         0.457
# 3    Scene Ah Scene Ah (Experimental EDM Mix)        0.2270         0.718
# 4  Gundellonaa X I Am a Disco Dancer (Mashup)        0.0153         0.689
#
#    energy  ...  loudness  mode  speechiness    tempo  time_signature  valence  \
# 0   0.970  ...    -5.994   0.0       0.1030  110.997             4.0    0.459
# 1   0.793  ...    -5.674   0.0       0.0952  164.995             3.0    0.821
# 2   0.491  ...    -8.937   0.0       0.1530  169.996             4.0    0.598
# 3   0.630  ...   -11.104   1.0       0.4450  169.996             4.0    0.362
# 4   0.748  ...    -9.637   1.0       0.1580  128.961             4.0    0.593
#
#                                            track_url  language  duration  \
# 0  https://open.spotify.com/track/2r0ROhr7pRN4MXD...     Tamil        97
# 1  https://open.spotify.com/track/4I38e6Dg52a2o2a...     Tamil       207
# 2  https://open.spotify.com/track/59NoiRhnom3lTeR...     Tamil        83
# 3  https://open.spotify.com/track/5uUqRQd385pvLxC...     Tamil       116
# 4  https://open.spotify.com/track/1KaBRg2xgNeCljm...     Tamil       130
#
#                                                dates
# 0  <bound method Index._get_level_values of Range...
# 1  <bound method Index._get_level_values of Range...
# 2  <bound method Index._get_level_values of Range...
# 3  <bound method Index._get_level_values of Range...
# 4  <bound method Index._get_level_values of Range...
#
# [5 rows x 23 columns]

# %%
sns.set_style(style='darkgrid')
plt.figure(figsize=(10,5))
popular = genre.sort_values('popularity', ascending=False).head(10)
sns.barplot(y = 'track_genre', x = 'popularity', data = popular).set(title='Top 5 Genres by Popularity')
# Out:
# [Text(0.5, 1.0, 'Top 5 Genres by Popularity')]

# %%
genre.head()
# Out:
#    Unnamed: 0                track_id                 artists  \
# 0           0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1           1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2           2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3           3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4           4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet
#
#                                           album_name  \
# 0                                             Comedy
# 1                                   Ghost (Acoustic)
# 2                                     To Begin Again
# 3  Crazy Rich Asians (Original Motion Picture Sou...
# 4                                            Hold On
#
#                    track_name  popularity  duration_ms  explicit  \
# 0                      Comedy          73       230666     False
# 1            Ghost - Acoustic          55       149610     False
# 2              To Begin Again          57       210826     False
# 3  Can't Help Falling In Love          71       201933     False
# 4                     Hold On          82       198853     False
#
#    danceability  energy  ...  loudness  mode  speechiness  acousticness  \
# 0         0.676  0.4610  ...    -6.746     0       0.1430        0.0322
# 1         0.420  0.1660  ...   -17.235     1       0.0763        0.9240
# 2         0.438  0.3590  ...    -9.734     1       0.0557        0.2100
# 3         0.266  0.0596  ...   -18.515     1       0.0363        0.9050
# 4         0.618  0.4430  ...    -9.681     1       0.0526        0.4690
#
#    instrumentalness  liveness  valence    tempo  time_signature  track_genre
# 0          0.000001    0.3580    0.715   87.917               4     acoustic
# 1          0.000006    0.1010    0.267   77.489               4     acoustic
# 2          0.000000    0.1170    0.120   76.332               4     acoustic
# 3          0.000071    0.1320    0.143  181.740               3     acoustic
# 4          0.000000    0.0829    0.167  119.949               4     acoustic
#
# [5 rows x 21 columns]

# %%
plt.title('Duration of songs in different Genres')
sns.color_palette('rocket', as_cmap=True)
sns.barplot(y='track_genre', x='duration_ms', data=genre)
plt.xlabel('Duration in milliseconds')
plt.ylabel('track_genre')
# Out:
# Text(0, 0.5, 'track_genre')

# %%
tracks.head()
# Out:
#                  track_id                                  track_name  \
# 0  2r0ROhr7pRN4MXDMT1fEmd                  Leo Das Entry (From "Leo")
# 1  4I38e6Dg52a2o2a8i5Q5PW                                AAO KILLELLE
# 2  59NoiRhnom3lTeRFaBzOev      Mayakiriye Sirikiriye - Orchestral EDM
# 3  5uUqRQd385pvLxC8JX3tXn    Scene Ah Scene Ah - Experimental EDM Mix
# 4  1KaBRg2xgNeCljmyxBH1mo  Gundellonaa X I Am A Disco Dancer - Mashup
#
#                                          artist_name  year  popularity  \
# 0                                Anirudh Ravichander  2024          59
# 1  Anirudh Ravichander, Pravin Mani, Vaishali Sri...  2024          47
# 2           Anirudh Ravichander, Anivee, Alvin Bruno  2024          35
# 3  Anirudh Ravichander, Bharath Sankar, Kabilan, ...  2024          24
# 4  Anirudh Ravichander, Benny Dayal, Leon James, ...  2024          22
#
#                                          artwork_url  \
# 0  https://i.scdn.co/image/ab67616d0000b273ce9c65...
# 1  https://i.scdn.co/image/ab67616d0000b273be1b03...
# 2  https://i.scdn.co/image/ab67616d0000b27334a1dd...
# 3  https://i.scdn.co/image/ab67616d0000b27332e623...
# 4  https://i.scdn.co/image/ab67616d0000b2735a59b6...
#
#                                    album_name  acousticness  danceability  \
# 0                  Leo Das Entry (From "Leo")        0.0241         0.753
# 1                                AAO KILLELLE        0.0851         0.780
# 2      Mayakiriye Sirikiriye (Orchestral EDM)        0.0311         0.457
# 3    Scene Ah Scene Ah (Experimental EDM Mix)        0.2270         0.718
# 4  Gundellonaa X I Am a Disco Dancer (Mashup)        0.0153         0.689
#
#    energy  ...  loudness  mode  speechiness    tempo  time_signature  valence  \
# 0   0.970  ...    -5.994   0.0       0.1030  110.997             4.0    0.459
# 1   0.793  ...    -5.674   0.0       0.0952  164.995             3.0    0.821
# 2   0.491  ...    -8.937   0.0       0.1530  169.996             4.0    0.598
# 3   0.630  ...   -11.104   1.0       0.4450  169.996             4.0    0.362
# 4   0.748  ...    -9.637   1.0       0.1580  128.961             4.0    0.593
#
#                                            track_url  language  duration  \
# 0  https://open.spotify.com/track/2r0ROhr7pRN4MXD...     Tamil        97
# 1  https://open.spotify.com/track/4I38e6Dg52a2o2a...     Tamil       207
# 2  https://open.spotify.com/track/59NoiRhnom3lTeR...     Tamil        83
# 3  https://open.spotify.com/track/5uUqRQd385pvLxC...     Tamil       116
# 4  https://open.spotify.com/track/1KaBRg2xgNeCljm...     Tamil       130
#
#                                                dates
# 0  <bound method Index._get_level_values of Range...
# 1  <bound method Index._get_level_values of Range...
# 2  <bound method Index._get_level_values of Range...
# 3  <bound method Index._get_level_values of Range...
# 4  <bound method Index._get_level_values of Range...
#
# [5 rows x 23 columns]
